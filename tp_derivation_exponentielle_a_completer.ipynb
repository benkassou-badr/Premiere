# %% [markdown]
# # TP : Dérivation - fonction exponentielle
# **PREMIÈRE MATHS SPÉ**

# %% [markdown]
# ## Utiliser le nombre $e$ et la fonction exponentielle avec Python
#
# - Importer le nombre $e$ depuis la bibliothèque `math`.
# - Afficher sa valeur.
# - Calculer $e^{-0.3}$.

# %%
# À compléter

# %% [markdown]
# ## Exercice 1
#
# On considère la fonction
#
# $$
# f(x)=e^x-3
# $$

# %% [markdown]
# ### 1. Fonction f
# Écrire une fonction Python `f(x)` qui renvoie l'image de `x`.

# %%
from math import exp

def f(x):
    # À compléter

# %% [markdown]
# ### 2. Coefficient directeur
# Écrire une fonction `coeff_dir` qui calcule le coefficient directeur entre deux points.

# %%
def coeff_dir(xA,yA,xB,yB):
    # À compléter

# %% [markdown]
# ### 3. Taux de variation

# %%
def taux_variation(f,a,h):
    # À compléter

# %% [markdown]
# Calculer le taux de variation de `f` entre `1` et `1.000001`.

# %%
# À compléter

# %% [markdown]
# ### 4. Tangente
# Écrire une fonction `coeff_tang` qui renvoie le coefficient directeur et l’ordonnée à l’origine de la tangente.

# %%
def coeff_tang(f,a):
    # À compléter

# %%
# Tester la fonction
# À compléter

# %% [markdown]
# ### 5. Table de valeurs

# %%
def tab_val(f):
    t=[]
    x=0
    for k in range(10):
        t.append(f(x))
        x=x+2
    return t

# %% [markdown]
# Adapter cette fonction pour recevoir `x0`, `p` et `n`.

# %%
def tab_val_param(f,x0,p,n):
    # À compléter

# %% [markdown]
# ## Exercice 2 — Méthode de Newton
#
# On cherche une solution de l'équation
#
# $$
# e^x-3=0
# $$

# %% [markdown]
# Écrire la fonction `etape_Newton`.

# %%
def etape_Newton(f,a):
    # À compléter

# %% [markdown]
# Fonction appliquant plusieurs itérations.

# %%
def appl_Newton(f,a,n):
    t=[a]
    for k in range(n):
        a=etape_Newton(f,a)
        t.append(a)
    return t

# %%
# Tester pour a=1 et n=10
# À compléter

# %% [markdown]
# Donner une valeur approchée de la solution.

# %%
# Calcul de la solution approchée
# À compléter

# %% [markdown]
# ## Exercice 3 — Approximation de e (Bernoulli)
#
# $$
# u_n=(1+\frac{1}{n})^n
# $$

# %%
def u(n):
    # À compléter

# %%
# Calculer u(1000)
# À compléter

# %%
from math import e

def precision(p):
    n=1
    while ... > ...:
        n = ...
    return n, u(n)
