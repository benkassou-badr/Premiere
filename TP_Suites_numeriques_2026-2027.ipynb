# %% [markdown]
# <div style="
#     width:100%;
#     box-sizing:border-box;
#     padding:24px 28px;
#     border-radius:14px;
#     background:linear-gradient(100deg,#102a43 0%,#1f5f8b 58%,#2c7da0 100%);
#     color:white;
#     font-family:Arial,Helvetica,sans-serif;
#     box-shadow:0 4px 14px rgba(0,0,0,.14);
# ">
#   <div style="font-size:14px;letter-spacing:1.5px;text-transform:uppercase;opacity:.92;">
#     Première — Spécialité Mathématiques
#   </div>
#   <div style="font-size:31px;font-weight:700;margin-top:5px;">
#     TP 1 — Suites numériques
#   </div>
#   <div style="font-size:17px;margin-top:7px;opacity:.96;">
#     Découvrir, modéliser et expérimenter avec Python
#   </div>
#   <div style="margin-top:18px;padding-top:12px;border-top:1px solid rgba(255,255,255,.45);
#               font-size:13px;display:flex;justify-content:space-between;gap:20px;flex-wrap:wrap;">
#     <span><strong>Hikmat.ma</strong></span>
#     <span>© Pr. Badr BENKASSOU</span>
#   </div>
# </div>

# %% [markdown]
# ### Informations élève
#
# **Nom et prénom :** ........................................................................
# **Classe :** .............................................  **Date :** .............................................
#
# > **Consigne générale.** Compléter les réponses et les cellules Python au fur et à mesure.
# > Les cellules contenant `...` sont volontairement incomplètes : remplacez les pointillés par votre code.

# %% [markdown]
# ## 1. Découvrir les suites avec Python
#
# Dans cette première partie, on travaille trois manières de définir une suite : **explicitement**, **par récurrence** et **comme suite géométrique**.

# %% [markdown]
# ### 1.1 Suite explicite
#
# On considère la suite $(u_n)$ définie par :
#
# \[
# u_n=2n^2-3n+1.
# \]
#
# **a)** Calculer $u_0$ et $u_{10}$.
#
# **Réponse :**
#
# - $u_0=$
# - $u_{10}=$

# %% [markdown]
# **b)** Compléter la fonction `suite_exp(n)` afin qu'elle renvoie le terme $u_n$.

# %%
def suite_exp(n):
    u = ...
    return ...

# %% [markdown]
# **c)** Déterminer avec Python $u_{10}$.

# %%
# À exécuter après avoir complété suite_exp
suite_exp(10)

# %% [markdown]
# ### 1.2 Suite définie par récurrence
#
# On considère la suite $(v_n)$ définie par :
#
# \[
# v_0=2
# \qquad\text{et}\qquad
# v_{n+1}=v_n+3.
# \]
#
# **a)** Calculer $v_1$ et $v_{10}$.
#
# **Réponse :**
#
# - $v_1=$
# - $v_{10}=$

# %% [markdown]
# **b)** Compléter la fonction `suite_rec(n)` afin qu'elle calcule successivement les termes à partir de $v_0$ et renvoie $v_n$.

# %%
def suite_rec(n):
    v = ...
    for k in range(...):
        v = ...
    return ...

# %% [markdown]
# **c)** Déterminer avec Python $v_{10}$.

# %%
# À exécuter après avoir complété suite_rec
suite_rec(10)

# %% [markdown]
# ### 1.3 Suite géométrique et limite
#
# On dispose d'une fonction permettant de calculer, à partir du terme $w_p$, le terme $w_n$ d'une suite géométrique de raison $q$.
#
# **a)** Compléter le programme ci-dessous.

# %%
def suite_geo(p, wp, q, n):
    w = ...
    for k in range(..., ...):
        w = ...
    return ...

# %% [markdown]
# **b)** Pour $w_0=2$ et $q=0{,}5$, calculer avec Python $w_{10}$, $w_{50}$ et $w_{100}$.

# %%
# À exécuter après avoir complété suite_geo
print("w_10  =", suite_geo(0, 2, 0.5, 10))
print("w_50  =", suite_geo(0, 2, 0.5, 50))
print("w_100 =", suite_geo(0, 2, 0.5, 100))

# %% [markdown]
# **c)** Compléter le tableau puis conjecturer le comportement de la suite selon la valeur de $q$.
#
# | $w_0 \backslash q$ | $-2$ | $-1$ | $-0{,}5$ | $0$ | $0{,}5$ | $1$ | $2$ |
# |---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|
# | $2$  |  |  |  |  |  |  |  |
# | $-2$ |  |  |  |  |  |  |  |
#
# **Conjecture :**
#
# ............................................................................................................................
#
# ............................................................................................................................

# %% [markdown]
# ## 2. Du tableur à Python
#
# On souhaite calculer les termes d'une suite à l'aide d'un tableur.

# %% [markdown]
# ### 2.1 Retrouver les relations de récurrence
#
# Pour chacune des feuilles de calcul, écrire la relation de récurrence vérifiée par la suite $(u_n)$.
#
# #### Feuille (a)
#
# |   | A | B |
# |:--:|:--:|:--:|
# | **1** | $n$ | $u_n$ |
# | **2** | $1$ | $2$ |
# | **3** | $2$ | `=2*B2-1` |
# | **4** | $3$ |  |
#
# **Relation de récurrence :**
#
# ............................................................................................................................

# %% [markdown]
# #### Feuille (b)
#
# |   | A | B |
# |:--:|:--:|:--:|
# | **1** | $n$ | $u_n$ |
# | **2** | $0$ | $-2$ |
# | **3** | $1$ | `=2*B2+3*A3` |
# | **4** | $2$ |  |
#
# **Relation de récurrence :**
#
# ............................................................................................................................

# %% [markdown]
# ### 2.2 Traduire les deux suites en Python
#
# Pour chacune des deux suites précédentes, écrire une fonction Python permettant de calculer et de renvoyer le terme $u_n$ pour un rang $n$ donné.

# %%
# Suite de la feuille (a)
def suite_tableur_a(n):
    # À compléter
    ...

# %%
# Tests personnels pour la feuille (a)
# Exemple : suite_tableur_a(3)

# %%
# Suite de la feuille (b)
def suite_tableur_b(n):
    # À compléter
    ...

# %%
# Tests personnels pour la feuille (b)
# Exemple : suite_tableur_b(3)

# %% [markdown]
# ## 3. Somme de termes
#
# On considère l'algorithme suivant :
#
# ```text
# S ← 0
# Pour k allant de 0 à 7 :
#     S ← S + 3 × 2^k
# Afficher S
# ```
#
# **1.** Expliquer, avec une phrase, ce que permet de calculer cet algorithme.
#
# **Réponse :**
#
# ............................................................................................................................
#
# **2.** Traduire cet algorithme en langage Python dans la cellule suivante.

# %%
# Traduction de l'algorithme
# À compléter

# %% [markdown]
# **3.** Déterminer la valeur de $S$ affichée par l'algorithme.
#
# **Réponse :** $S=$

# %% [markdown]
# ## 4. Révisions avant un examen
#
# Un élève prépare un examen. On note $M_n$ la proportion du programme qu'il maîtrise au bout de $n$ jours de révision. Au départ,
#
# \[
# M_0=0{,}2.
# \]
#
# Chaque jour, il conserve $92\,\%$ de ce qu'il maîtrisait déjà et apprend $20\,\%$ de ce qu'il ne maîtrisait pas encore.

# %% [markdown]
# **1.** Expliquer pourquoi
#
# \[
# M_{n+1}=0{,}92M_n+0{,}20(1-M_n).
# \]
#
# **Réponse :**
#
# ............................................................................................................................
#
# **2.** Montrer que
#
# \[
# M_{n+1}=0{,}72M_n+0{,}20.
# \]
#
# **Démonstration :**
#
# ............................................................................................................................

# %% [markdown]
# **3.** Calculer $M_1$, $M_2$ et $M_3$. Arrondir au millième si nécessaire.
#
# - $M_1=$
# - $M_2=$
# - $M_3=$

# %% [markdown]
# **4.** Compléter la fonction Python suivante afin qu'elle renvoie la proportion du programme maîtrisée après $n$ jours.

# %%
def maitrise(n):
    M = ...
    for i in range(...):
        M = ...
    return M

# %% [markdown]
# **5.** On pose
#
# \[
# R_n=M_n-\frac57.
# \]
#
# Montrer que $(R_n)$ est une suite géométrique.
#
# **Démonstration :**
#
# ............................................................................................................................
#
# ............................................................................................................................

# %% [markdown]
# **6.** Exprimer $M_n$ en fonction de $n$, puis déterminer la limite de la suite $(M_n)$.
#
# **Expression de $M_n$ :**
#
# \[
# M_n=\qquad\qquad
# \]
#
# **Limite :**
#
# \[
# \lim_{n\to+\infty}M_n=\qquad\qquad
# \]

# %% [markdown]
# **7.** Compléter la fonction `objectif()` afin qu'elle renvoie le premier jour où l'élève maîtrise **strictement plus de $70\,\%$** du programme.

# %%
def objectif():
    n = 0
    M = ...
    while False:  # À remplacer par la condition correcte
        M = ...
        n = n + 1
    return n

# %% [markdown]
# **8.** Quelle valeur obtient-on ?

# %%
# À exécuter après avoir complété objectif
objectif()

# %% [markdown]
# **Réponse :** ..............................................................................................................

# %% [markdown]
# ## 5. Fibonacci et le nombre d'or
#
# La suite de Fibonacci est définie par :
#
# \[
# F_0=0,\qquad F_1=1,\qquad F_{n+2}=F_{n+1}+F_n.
# \]
#
# On souhaite observer numériquement le comportement des quotients
#
# \[
# \frac{F_{n+1}}{F_n}
# \]
#
# lorsque $n$ devient grand.

# %% [markdown]
# **1.** Calculer $F_2$, $F_3$, $F_4$, $F_5$ et $F_6$.
#
# - $F_2=$
# - $F_3=$
# - $F_4=$
# - $F_5=$
# - $F_6=$

# %% [markdown]
# **2.** Compléter la fonction Python suivante afin qu'elle construise et renvoie la liste des termes $F_0,F_1,\ldots,F_N$.

# %%
def fibonacci(N):
    termes = [..., ...]
    for k in range(...):
        termes.append(...)  # À compléter
    return termes

# %% [markdown]
# **3.** Écrire un programme qui affiche les quotients
#
# \[
# \frac{F_{n+1}}{F_n}
# \]
#
# pour $1\leq n\leq 15$.

# %%
# Calcul et affichage des quotients
# À compléter

# %% [markdown]
# **4.** Conjecturer la limite de ces quotients.
#
# **Conjecture :**
#
# ............................................................................................................................

# %% [markdown]
# **5.** Comparer la conjecture avec le nombre
#
# \[
# \varphi=\frac{1+\sqrt5}{2}.
# \]
#
# Utiliser Python si nécessaire.

# %%
from math import sqrt

# Calculer ici une valeur approchée de phi puis comparer.
# À compléter

# %% [markdown]
# **6.** Montrer que $\varphi$ vérifie
#
# \[
# \varphi^2=\varphi+1.
# \]
#
# **Démonstration :**
#
# ............................................................................................................................
#
# **7.** Expliquer le lien entre cette relation et la récurrence de Fibonacci.
#
# **Réponse :**
#
# ............................................................................................................................
#
# ............................................................................................................................

# %% [markdown]
# <hr style="margin-top:28px;border:0;border-top:1px solid #b8c5cf;">
#
# <div style="text-align:center;font-family:Arial,Helvetica,sans-serif;font-size:12px;color:#52606d;padding:8px 0 2px;">
#   © Hikmat.ma — Pr. Badr BENKASSOU
# </div>
